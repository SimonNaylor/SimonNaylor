# %% [markdown]
# ### First I filtered by district, as districts 1 and 4 shared the same number of stops. Then, I sorted if an arrest was made or not. Simple, because I think the scope of this project is to show how well we use JS.

# %%
import numpy as np
import pandas as pd
policeDF = pd.read_csv("denver-1.nov.csv")

# %%
policeDF.head()
# Out:
#    raw_row_number        date      time                         location  \
# 0               1  2012-11-13  00:02:22             8500 W CRESTLINE AVE
# 1              16  2012-11-29  00:25:01             8500 W CRESTLINE AVE
# 2              72  2012-11-23  22:58:10               4830 S HOLLAND WAY
# 3             121  2012-11-27  17:48:33                 4885 S QUEBEC ST
# 4             138  2012-11-14  23:46:58  W LAYTON AVE / S WADSWORTH BLVD
#
#          lat         lng district precinct        type  \
# 0  39.618329 -105.092691        4      423   vehicular
# 1  39.618329 -105.092691        4      423   vehicular
# 2  39.630666 -105.102551        4      423   vehicular
# 3  39.626174 -104.904062        3      324  pedestrian
# 4  39.630150 -105.081693        4      423   vehicular
#
#                   disposition  arrest_made  citation_issued  warning_issued  \
# 0  K - Street Check Completed        False            False           False
# ...

# %%
policeDF["precinct"].value_counts()
# Out:
# 223     369
# 311     294
# 411     293
# 412     290
# 621     281
# 611     278
# 111     271
# 211     256
# 421     233
# 121     218
# 221     210
# 521     207
# 212     202
# 122     193
# 312     187
# 612     174
# 423     171
# 422     171
# 213     169
# 112     167
# None    166
# 113     155
# 123     154
# 623     147
# 313     140
# 222     132
# 511     132
# 622     124
# 512     115
# 322     104
# 323      84
# 522      73
# 314      66
# 321      53
# 523      44
# 324      40
# 759       2
# Name: precinct, dtype: int64

# %%
policeDF["arrest_made"].value_counts()
# Out:
# False    5380
# True      985
# Name: arrest_made, dtype: int64

# %%
policeDF["district"].value_counts()
# Out:
# 2       1338
# 1       1158
# 4       1158
# 6       1004
# 3        968
# 5        571
# None     166
# 7          2
# Name: district, dtype: int64

# %%
_c0 = policeDF['arrest_made'] == True
_c1 = policeDF['district'].isin(['1','2'])
#_c2 = policeDF['district'] == '4'
policearrestDF = policeDF[_c0 & _c1]
print(policearrestDF.shape)
policearrestDF
# Out:
# (454, 14)
#       raw_row_number        date      time                    location  \
# 2022          200822  2012-11-16  00:18:16            777 N BANNOCK ST
# 2024          200842  2012-11-15  22:57:06            777 N BANNOCK ST
# 2025          200865  2012-11-11  03:14:28         600-BLK N WINONA CT
# 2026          201213  2012-11-14  08:10:32      E 6TH AVE / N ADAMS ST
# 2028          201306  2012-11-02  06:21:57   W 7TH AVE / N KALAMATH ST
# ...              ...         ...       ...                         ...
# 5923          611157  2012-11-14  00:32:46  E 47TH AVE / N THOMPSON CT
# 5928          611737  2012-11-17  21:34:34   E 48TH AVE / N CLAYTON ST
# 5930          611960  2012-11-26  01:59:05    I70 WB / N SHERIDAN BLVD
# 5933          612147  2012-11-08  06:46:53         4757 N VASQUEZ BLVD
# 5934          612327  2012-11-20  22:51:16    I70 WB / N BRIGHTON BLVD
#
#             lat         lng district precinct        type  \
# ...

# %%
_c0 = policeDF['arrest_made'] == True
_c1 = policeDF['district'].isin(['1','2'])
#_c2 = policeDF['district'] == '4'
policearrestDF = policeDF[_c0 & _c1]
print(policearrestDF.shape)
policearrestDF
# Out:
# (454, 14)
#       raw_row_number        date      time                    location  \
# 2022          200822  2012-11-16  00:18:16            777 N BANNOCK ST
# 2024          200842  2012-11-15  22:57:06            777 N BANNOCK ST
# 2025          200865  2012-11-11  03:14:28         600-BLK N WINONA CT
# 2026          201213  2012-11-14  08:10:32      E 6TH AVE / N ADAMS ST
# 2028          201306  2012-11-02  06:21:57   W 7TH AVE / N KALAMATH ST
# ...              ...         ...       ...                         ...
# 5923          611157  2012-11-14  00:32:46  E 47TH AVE / N THOMPSON CT
# 5928          611737  2012-11-17  21:34:34   E 48TH AVE / N CLAYTON ST
# 5930          611960  2012-11-26  01:59:05    I70 WB / N SHERIDAN BLVD
# 5933          612147  2012-11-08  06:46:53         4757 N VASQUEZ BLVD
# 5934          612327  2012-11-20  22:51:16    I70 WB / N BRIGHTON BLVD
#
#             lat         lng district precinct        type  \
# ...

# %%
filterDF = policeDF['district'].isin(['1','2'])
filterDF
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6360    False
# 6361    False
# 6362    False
# 6363    False
# 6364    False
# Name: district, Length: 6365, dtype: bool

# %%
subsetDataFrame = policeDF[policeDF['district'].isin(['1', '2']) ]
subsetDataFrame
# Out:
#       raw_row_number        date      time                      location  \
# 2005          199276  2012-11-13  10:34:44           600-BLK N BRYANT ST
# 2008          199817  2012-11-11  12:35:31      N DETROIT ST / E 7TH AVE
# 2009          199899  2012-11-12  22:41:23            700-ELATI N FOX ST
# 2011          200032  2012-11-24  00:57:29                800 N HAZEL CT
# 2016          200122  2012-11-07  07:20:54          0 W 6TH AVE / I25 NB
# ...              ...         ...       ...                           ...
# 5946          613198  2012-11-13  14:16:35  W REGIS BLVD / N LOWELL BLVD
# 5951          613653  2012-11-29  08:42:31       5000-BLK N VASQUEZ BLVD
# 5952          613657  2012-11-18  01:38:07           5000 N VASQUEZ BLVD
# 5954          613985  2012-11-07  16:05:51    E 51ST AVE / N BROADWAY ST
# 5963          614795  2012-11-10  17:04:21       I70 EB / N FEDERAL BLVD
#
#             lat         lng district precinct        type  \
# ...

# %%
fiveHourGames = policeDF[policeDF['district']== "2"]
fiveHourGames
# Out:
#       raw_row_number        date      time                    location  \
# 2008          199817  2012-11-11  12:35:31    N DETROIT ST / E 7TH AVE
# 2017          200359  2012-11-15  08:53:08  E 7TH AVE / N JOSEPHINE ST
# 2026          201213  2012-11-14  08:10:32      E 6TH AVE / N ADAMS ST
# 2027          201217  2012-11-13  23:41:18      E 6TH AVE / N ADAMS ST
# 2036          202065  2012-11-28  10:54:22  N JOSEPHINE ST / E 7TH AVE
# ...              ...         ...       ...                         ...
# 5929          611744  2012-11-27  09:02:33   E 48TH AVE / N CLAYTON ST
# 5933          612147  2012-11-08  06:46:53         4757 N VASQUEZ BLVD
# 5934          612327  2012-11-20  22:51:16    I70 WB / N BRIGHTON BLVD
# 5951          613653  2012-11-29  08:42:31     5000-BLK N VASQUEZ BLVD
# 5952          613657  2012-11-18  01:38:07         5000 N VASQUEZ BLVD
#
#             lat         lng district precinct        type  \
# ...

# %%
subsetDataFrame = policeDF[policeDF['district'].isin(['1', '4']) ]
subsetDataFrame
# Out:
#       raw_row_number        date      time                         location  \
# 0                  1  2012-11-13  00:02:22             8500 W CRESTLINE AVE
# 1                 16  2012-11-29  00:25:01             8500 W CRESTLINE AVE
# 2                 72  2012-11-23  22:58:10               4830 S HOLLAND WAY
# 4                138  2012-11-14  23:46:58  W LAYTON AVE / S WADSWORTH BLVD
# 5                166  2012-11-27  00:49:39                4490 S KIPLING ST
# ...              ...         ...       ...                              ...
# 5941          612884  2012-11-26  09:22:06                   4915 N GRAY ST
# 5944          613043  2012-11-15  22:21:02             4900 N WASHINGTON ST
# 5946          613198  2012-11-13  14:16:35     W REGIS BLVD / N LOWELL BLVD
# 5954          613985  2012-11-07  16:05:51       E 51ST AVE / N BROADWAY ST
# 5963          614795  2012-11-10  17:04:21          I70 EB / N FEDERAL BLVD
#
# ...

# %%
fullyFilteredDF = pd.crosstab(subsetDataFrame['district'],subsetDataFrame['arrest_made'])
fullyFilteredDF
#jsonDF = subsetDataFrame['district','arrest_made']
# Out:
# arrest_made  False  True
# district
# 1              958    200
# 4             1009    149

# %%
fullyFilteredDF.to_json (r'C:\Users\simonnaylor\Desktop\fullyFiltered.json')
